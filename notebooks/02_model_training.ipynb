# %% [markdown]
# # Model Training and Evaluation
#
# This notebook demonstrates model training, evaluation, and comparison.

# %%
import sys
sys.path.append('..')
from api.train_model import HealthcareAdmissionModel

print('✓ Ready to train models')

# %%
# Train the model
trainer = HealthcareAdmissionModel()
df = trainer.load_data()
X_train, X_test, y_train, y_test = trainer.preprocess_data(df)
best_model = trainer.train_models(X_train, X_test, y_train, y_test)

# %%
# Save the model
trainer.save_model()
