# %% [markdown]
# # Healthcare Admission Prediction - Exploratory Data Analysis
#
# This notebook provides a comprehensive analysis of patient data for admission prediction modeling.
#
# ## Objectives
# - Understand the data structure and quality
# - Analyze feature distributions
# - Identify patterns and correlations
# - Prepare insights for model development

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings

warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 3)

print("✓ Libraries imported successfully")

# %%
# Check for missing values
print("Missing Values:")
print(df.isnull().sum())
print("\nMissing Percentage:")
print((df.isnull().sum() / len(df) * 100).round(2))
print("\n" + "="*60)
print("Duplicate Rows:", df.duplicated().sum())

# %% [markdown]
# ## 3. Data Quality Check

# %%
# Data info
print("Dataset Information:")
print(df.info())
print("\n" + "="*60)
print("Statistical Summary:")
df.describe()

# %%
# Load the dataset
df = pd.read_csv('../data/processed/patient_data_processed.csv')

print("Dataset Shape:", df.shape)
print("\nFirst 5 rows:")
df.head()

# %% [markdown]
# ## 2. Load and Inspect Data
